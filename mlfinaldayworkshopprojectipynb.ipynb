# %% [markdown]
# <a href="https://colab.research.google.com/github/Darshikartisto/deep-dive-into-industry-trendsfinal/blob/main/mlfinaldayworkshopprojectipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **COMPUTER VISION **
#
# 1) Classification
# 2) Object detention
# 3) Segmentation

# %%
#install framework
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.5/586.5 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 29.0 MB/s eta 0:00:00
# ...

# %%
#classification
from ultralytics import YOLO
CLASSIFIER_ENGINE=YOLO("yolov8n-cls.pt")
RESULT = CLASSIFIER_ENGINE.predict(source="2.jpg", save=True, save_txt=True)
# Out:
# image 1/1 /content/2.jpg: 224x224 zebra 1.00, tiger 0.00, tiger_cat 0.00, hartebeest 0.00, screw 0.00, 13.1ms
# Speed: 0.7ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict2
# 1 label saved to runs/classify/predict2/labels

# %%
DETECTION_ENGINE = YOLO("yolov8n.pt")
RESULT = DETECTION_ENGINE.predict(source="2.jpg", save=True,save_txt=True)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 77.7MB/s]
#
# image 1/1 /content/2.jpg: 448x640 3 birds, 1 zebra, 141.0ms
# Speed: 4.2ms preprocess, 141.0ms inference, 15.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 1 label saved to runs/detect/predict/labels

# %%
from ultralytics import YOLO
SEGMENTATION_ENGINE=YOLO("yolov8n-seg.pt")
RESULT=SEGMENTATION_ENGINE.predict(source="2.jpg",save=True,save_txt=True)
# Out:
# image 1/1 /content/2.jpg: 448x640 6 birds, 1 zebra, 227.5ms
# Speed: 2.4ms preprocess, 227.5ms inference, 18.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict
# 1 label saved to runs/segment/predict/labels

# %%
DETECTION_ENGINE = YOLO("yolov8n.pt")
RESULT = DETECTION_ENGINE.predict(source="HD.mkv", save=True,save_txt=True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/305) /content/HD.mkv: 384x640 1 person, 127.3ms
# video 1/1 (2/305) /content/HD.mkv: 384x640 2 persons, 1 car, 119.8ms
# video 1/1 (3/305) /content/HD.mkv: 384x640 3 persons, 2 cars, 105.3ms
# video 1/1 (4/305) /content/HD.mkv: 384x640 2 persons, 2 cars, 98.3ms
# video 1/1 (5/305) /content/HD.mkv: 384x640 2 persons, 2 cars, 101.5ms
# video 1/1 (6/305) /content/HD.mkv: 384x640 2 persons, 3 cars, 91.4ms
# ...
